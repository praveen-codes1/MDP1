# %%
import pandas as pd
df=pd.read_csv('dtc.csv')
df.head()
# Out:
#        Origin  Destination                              Pouch No        Date  \
# 0      Nagpur   Jamshedpur  55e275ad-8da9-49c9-986c-93134fef2c19  2025-06-25
# 1      Jaipur        Vizag  7fab4175-11b2-4090-a0ed-4571ccd68878  2025-06-27
# 2     Lucknow  Bhubaneswar  5231428d-b524-433e-8043-45c7e39a94aa  2025-06-27
# 3  Coimbatore       Mumbai  2f556b38-298d-4e8c-9310-4e6a3a5fbe61  2025-06-11
# 4      Meerut   Vijayawada  c3154041-34eb-435e-94d8-0900e6a9ed01  2025-07-01
#
#       Sender's Name  Sender Phone  \
# 0    Megha Majumdar    6137840452
# 1       Nanda-Saraf      52907142
# 2    Contractor LLC    5081512738
# 3      Krishna Hans    1518559754
# 4  Kuruvilla-Tiwari    1666398391
#
#                                       Sender Address Sender City  \
# 0  H.No. 425 Varughese Chowk, Above Shop, Nagpur,...      Nagpur
# 1  48/880, Tripathi, Above Shop, Jaipur, Rajastha...      Jaipur
# 2  257, Kulkarni Path, Above Shop, Lucknow, Uttar...     Lucknow
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49639 entries, 0 to 49638
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Origin                 49639 non-null  object
#  1   Destination            49639 non-null  object
#  2   Pouch No               49639 non-null  object
#  3   Date                   49639 non-null  object
#  4   Sender's Name          49639 non-null  object
#  5   Sender Phone           49639 non-null  int64
#  6   Sender Address         49639 non-null  object
#  7   Sender City            49639 non-null  object
#  8   Sender State           49639 non-null  object
#  9   Sender Pincode         49639 non-null  int64
#  10  Sender GSTIN           26778 non-null  object
#  11  Total Pieces           49639 non-null  int64
#  12  Actual Wt              49639 non-null  float64
#  13  Volumetric Wt          49639 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Sender Phone  Sender Pincode  Total Pieces     Actual Wt  \
# count  4.963900e+04    49639.000000  49639.000000  49639.000000
# mean   5.010054e+09   499786.484055      2.994480      6.167263
# std    2.892645e+09   288607.647965      1.415086      3.375089
# min    1.710800e+04        1.000000      1.000000      0.300000
# 25%    2.479984e+09   248197.500000      2.000000      3.260000
# 50%    5.018929e+09   499479.000000      3.000000      6.190000
# 75%    7.533459e+09   748322.000000      4.000000      9.080000
# max    9.999872e+09   999981.000000      5.000000     12.000000
#
#        Volumetric Wt  Chargeable Wt  Recipient Phone  Receiver Pincode  \
# count   49639.000000   49639.000000     4.963900e+04      49639.000000
# mean        7.716568       7.716568     4.973767e+09     500547.941115
# std         3.476748       3.476748     2.883664e+09     287851.384963
# min         0.440000       0.440000     2.289200e+05          2.000000
# ...

# %%
df.tail()
# Out:
#           Origin Destination                              Pouch No  \
# 49634   Varanasi      Bhopal  78ad9246-96ca-40e0-a77e-1f5f601b2114
# 49635      Patna  Jamshedpur  be889bde-61ea-460c-8dc8-6bdaf7a91579
# 49636    Kolkata  Aurangabad  17a77c5d-ccdf-42c1-adc0-ec5b89b84154
# 49637   Srinagar  Aurangabad  9eae5dad-b5c0-4047-b1fe-a340dbc4e41e
# 49638  Ahmedabad    Amritsar  fe45d57f-d3ab-4c39-b60a-8abebae5c224
#
#              Date                    Sender's Name  Sender Phone  \
# 49634  2025-07-04                   Chavvi Kashyap    6657295176
# 49635  2025-06-15  Chakrabarti, Pandit and Agrawal    5273847382
# 49636  2025-06-06                       Arya Shere    4416278858
# 49637  2025-07-05                  Harita Dhaliwal    5568995605
# 49638  2025-06-24                       Warhi Nath    2408553775
#
#                                           Sender Address Sender City  \
# 49634  H.No. 66, Chaudry Marg, Behind School, Varanas...    Varanasi
# ...

# %%
df.columns
# Out:
# Index(['Origin', 'Destination', 'Pouch No', 'Date', 'Sender's Name',
#        'Sender Phone', 'Sender Address', 'Sender City', 'Sender State',
#        'Sender Pincode', 'Sender GSTIN', 'Total Pieces', 'Actual Wt',
#        'Volumetric Wt', 'Chargeable Wt', 'Paperwork', 'Sender Signature',
#        'Sender Date', 'Recipient Name', 'Recipient Phone', 'Recipient Address',
#        'Recipient City', 'Receiver State', 'Receiver Pincode', 'Description',
#        'Value Added Services', 'Consignment No', 'Expiry Date', 'Booking Code',
#        'Recipient GSTIN', 'Receiver Name', 'Relationship', 'Company Stamp',
#        'Receiver Signature', 'Receive Date', 'Tariff', 'VAS Charges',
#        'Total Amount', 'Mode', 'Risk Surcharge', 'Mode of Payment',
#        'Nature of Consignment'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Origin                       0
# Destination                  0
# Pouch No                     0
# Date                         0
# Sender's Name                0
# Sender Phone                 0
# Sender Address               0
# Sender City                  0
# Sender State                 0
# Sender Pincode               0
# Sender GSTIN             22861
# Total Pieces                 0
# Actual Wt                    0
# Volumetric Wt                0
# Chargeable Wt                0
# Paperwork                    0
# Sender Signature         19828
# Sender Date                  0
# Recipient Name               0
# Recipient Phone              0
# Recipient Address            0
# Recipient City               0
# Receiver State               0
# Receiver Pincode             0
# Description                  0
# Value Added Services     10240
# Consignment No               0
# Expiry Date                  0
# Booking Code                 0
# Recipient GSTIN          35773
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Origin  Destination  Pouch No                              Date        Sender's Name                Sender Phone  Sender Address                                                       Sender City  Sender State    Sender Pincode  Sender GSTIN    Total Pieces  Actual Wt  Volumetric Wt  Chargeable Wt  Paperwork  Sender Signature  Sender Date  Recipient Name            Recipient Phone  Recipient Address                                                      Recipient City  Receiver State  Receiver Pincode  Description                                    Value Added Services  Consignment No  Expiry Date  Booking Code  Recipient GSTIN  Receiver Name             Relationship  Company Stamp  Receiver Signature  Receive Date  Tariff  VAS Charges  Total Amount  Mode       Risk Surcharge  Mode of Payment  Nature of Consignment
# ...

# %%
print(df)
# Out:
#            Origin  Destination                              Pouch No  \
# 0          Nagpur   Jamshedpur  55e275ad-8da9-49c9-986c-93134fef2c19
# 1          Jaipur        Vizag  7fab4175-11b2-4090-a0ed-4571ccd68878
# 2         Lucknow  Bhubaneswar  5231428d-b524-433e-8043-45c7e39a94aa
# 3      Coimbatore       Mumbai  2f556b38-298d-4e8c-9310-4e6a3a5fbe61
# 4          Meerut   Vijayawada  c3154041-34eb-435e-94d8-0900e6a9ed01
# ...           ...          ...                                   ...
# 49634    Varanasi       Bhopal  78ad9246-96ca-40e0-a77e-1f5f601b2114
# 49635       Patna   Jamshedpur  be889bde-61ea-460c-8dc8-6bdaf7a91579
# 49636     Kolkata   Aurangabad  17a77c5d-ccdf-42c1-adc0-ec5b89b84154
# 49637    Srinagar   Aurangabad  9eae5dad-b5c0-4047-b1fe-a340dbc4e41e
# 49638   Ahmedabad     Amritsar  fe45d57f-d3ab-4c39-b60a-8abebae5c224
#
#              Date                    Sender's Name  Sender Phone  \
# 0      2025-06-25                   Megha Majumdar    6137840452
# ...

# %%
for col in df.columns:
    col=col.strip().lower().replace(' ','_')
df.columns
# Out:
# Index(['origin', 'destination', 'pouch_no', 'date', 'sender's_name',
#        'sender_phone', 'sender_address', 'sender_city', 'sender_state',
#        'sender_pincode', 'sender_gstin', 'total_pieces', 'actual_wt',
#        'volumetric_wt', 'chargeable_wt', 'paperwork', 'sender_signature',
#        'sender_date', 'recipient_name', 'recipient_phone', 'recipient_address',
#        'recipient_city', 'receiver_state', 'receiver_pincode', 'description',
#        'value_added_services', 'consignment_no', 'expiry_date', 'booking_code',
#        'recipient_gstin', 'receiver_name', 'relationship', 'company_stamp',
#        'receiver_signature', 'receive_date', 'tariff', 'vas_charges',
#        'total_amount', 'mode', 'risk_surcharge', 'mode_of_payment',
#        'nature_of_consignment'],
#       dtype='object')
