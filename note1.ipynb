# %%
import pandas as pd
df=pd.read_csv('Disney_movies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           525 non-null    int64
#  1   movie_name           525 non-null    object
#  2   Directed by          525 non-null    object
#  3   Story by             169 non-null    object
#  4   Based on             290 non-null    object
#  5   Produced by          517 non-null    object
#  6   Starring             493 non-null    object
#  7   Music by             518 non-null    object
#  8   Productioncompany    204 non-null    object
#  9   Distributed by       525 non-null    object
#  10  Release dates        197 non-null    object
#  11  Running time         516 non-null    object
#  12  Country              454 non-null    object
#  13  Language             502 non-null    object
#  14  Budget               314 non-null    object
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                   movie_name  \
# 0           0  Snow White and the Seven Dwarfs (1937 film)
# 1           1                        Pinocchio (1940 film)
# 2           2                         Fantasia (1940 film)
# 3           3             The Reluctant Dragon (1941 film)
# 4           4                                        Dumbo
#
#                                          Directed by  \
# 0  ['David Hand', 'Perce Pearce', 'Larry Morey', ...
# 1  ['Ben Sharpsteen', 'Hamilton Luske', 'Norman F...
# 2  ['James Algar', 'Ben Sharpsteen', 'David D. Ha...
# 3  ['Alfred Werker', 'Hamilton Luske', 'Jack Cutt...
# 4  ['Ben Sharpsteen', 'Norman Ferguson', 'Wilfred...
#
#                                             Story by  \
# 0     ['Ted Sears', 'Earl Hurd', 'Merrill De Maris']
# 1  ['Ted Sears', 'Erdman Penner', 'Ted Sears\nOtt...
# 2                       ['Joe Grant', 'Dick Huemer']
# 3                                                NaN
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0                     movie_name          Directed by  \
# 520         520                    Elio (film)    ['Adrian Molina']
# 521         521          Out of My Mind (film)         Amber Sealey
# 522         522        Young Woman and the Sea      Joachim Rønning
# 523         523  Lilo & Stitch (upcoming film)  Dean Fleischer Camp
# 524         524                     Tron: Ares      Joachim Rønning
#
#                                    Story by  \
# 520                                     NaN
# 521                                     NaN
# 522                                     NaN
# 523                                     NaN
# 524  ['Steven Lisberger', 'Bonnie MacBird']
#
#                                               Based on  \
# 520                                                NaN
# 521             ['Out of My Mind', 'Sharon M. Draper']
# 522  ['Young Woman and the Sea: How Trudy Ederle Co...
# 523  ['Lilo & Stitch', 'Chris Sanders', 'Dean DeBlo...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'movie_name', 'Directed by', 'Story by', 'Based on',
#        'Produced by', 'Starring', 'Music by', 'Productioncompany',
#        'Distributed by', 'Release dates', 'Running time', 'Country',
#        'Language', 'Budget', 'Box office', 'Narrated by', 'Cinematography',
#        'Release date', 'Written by', 'Edited by', 'Screenplay by', 'Countries',
#        'Productioncompanies'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# movie_name               0
# Directed by              0
# Story by               356
# Based on               235
# Produced by              8
# Starring                32
# Music by                 7
# Productioncompany      321
# Distributed by           0
# Release dates          328
# Running time             9
# Country                 71
# Language                23
# Budget                 211
# Box office             128
# Narrated by            466
# Cinematography         126
# Release date           200
# Written by             301
# Edited by               42
# Screenplay by          263
# Countries              458
# Productioncompanies    204
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
print(df)

# %%
for col in df.columns:
    col=col.strip().lower().replace(' ','_')
df.columns
# Out:
# Index(['Unnamed: 0', 'movie_name', 'Directed by', 'Story by', 'Based on',
#        'Produced by', 'Starring', 'Music by', 'Productioncompany',
#        'Distributed by', 'Release dates', 'Running time', 'Country',
#        'Language', 'Budget', 'Box office', 'Narrated by', 'Cinematography',
#        'Release date', 'Written by', 'Edited by', 'Screenplay by', 'Countries',
#        'Productioncompanies'],
#       dtype='object')

# %%
mcols=[col for col in df.columns if df[col].isnull().any()]
df[mcols].head()
# Out:
#                                             Story by  \
# 0     ['Ted Sears', 'Earl Hurd', 'Merrill De Maris']
# 1  ['Ted Sears', 'Erdman Penner', 'Ted Sears\nOtt...
# 2                       ['Joe Grant', 'Dick Huemer']
# 3                                                NaN
# 4                       ['Joe Grant', 'Dick Huemer']
#
#                                            Based on      Produced by  \
# 0                  ['Snow White', 'Brothers Grimm']  ['Walt Disney']
# 1  ['The Adventures of Pinocchio', 'Carlo Collodi']  ['Walt Disney']
# 2                                               NaN  ['Walt Disney']
# 3                                               NaN  ['Walt Disney']
# 4                                 ['Helen Aberson']  ['Walt Disney']
#
#                                             Starring  \
# 0  ['Adriana Caselotti', 'Roy Atwell', 'Pinto Col...
# 1  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 2              ['Leopold Stokowski', 'Deems Taylor']
# ...
